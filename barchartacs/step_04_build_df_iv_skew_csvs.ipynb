# %% [markdown]
# This notebooks builds 2 csv files for any commodity that you specify in the variable `SYMBOL_TO_RESEARCH`
#
# The csv files are then written to as follows:
# ```
# df_iv_final.to_csv(f'./temp_folder/df_iv_final_{SYMBOL_TO_RESEARCH}.csv',index=False)
# df_iv_skew.to_csv(f'./temp_folder/df_iv_skew_{SYMBOL_TO_RESEARCH}.csv',index=False)
# ```
#
# They can be copied to the volgrid project to be used by the Dash server that displays skew graphs for ES, CL and CB (Brent).

# %%
import zipfile
import glob
import pandas as pd
import numpy as np

from argparse import ArgumentParser
from argparse import RawDescriptionHelpFormatter
import sys
import os
if  not './' in sys.path:
    sys.path.append('./')
if  not '../' in sys.path:
    sys.path.append('../')

from barchartacs import build_db
from barchartacs import db_info
import plotly.graph_objs as go
from plotly.offline import  init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.tools as tls
from plotly.graph_objs.layout import Font,Margin
from IPython import display

import datetime
import io
from tqdm import tqdm,tqdm_notebook
from barchartacs import pg_pandas as pg
import mibian
import py_vollib
import importlib
from py_vollib import black
from py_vollib.black import implied_volatility
import ipdb
import traceback

MONTH_CODES = 'FGHJKMNQUVXZ'
DICT_MONTH_NUMS = {MONTH_CODES[i]:i+1 for i in range(len(MONTH_CODES))}

# importlib.reload(db_info)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### important global variables

# %%
DEBUG_IT=False
opttab = 'sec_schema.options_table'
futtab = 'sec_schema.underlying_table'
pga = db_info.get_db_info()
SYMBOL_TO_RESEARCH = 'ES'
STRIKE_DIVISORS = {}

# df_expiry_dates_additions = pd.read_csv('df_expiry_dates_additions.csv')
df_expiry_dates_additions = pd.read_csv('live_option_expirations.csv')
# Out:
#   sec_db

# %%
USE_PYVOL = True
def lam_pyvol(r):
    try:
        return implied_volatility.implied_volatility(r.close_x,r.close_y,r.strike,.02,r.dte/365, r.pc.lower())
    except:
        return -1
# lam_pyvol = lambda r:implied_volatility.implied_volatility(r.close_x,r.close_y,r.strike,.02,r.dte/365, r.pc.lower())
lam_mibian = lambda r:mibian.BS([r.close_y,r.strike,2,r.dte], callPrice=r.close_x).impliedVolatility

def get_implieds(df,df_expiry_dates,contract):
    df2 = df[['symbol','contract_num','pc','settle_date','strike','close_x','close_y']]
    df2 = df2[(((df2.pc=='C' )& (df2.strike>=df2.close_y)) | ((df2.pc=='P' ) & (df2.strike<df2.close_y)))  & (df2.symbol.str.contains(contract))]
    cnum = _get_contract_number_from_symbol(contract)
    df2 = df2[df2.contract_num==2]
    phigh = df2.close_y.max()
    plow = df2.close_y.min()
    high_strike = round(phigh * 1.3)
    low_strike = round(plow * .7)
    df2 = df2[(df2.strike>=low_strike) & (df2.strike<=high_strike)]

    df9 = df2[df2.symbol==contract]
    df9 = df9.merge(df_expiry_dates.rename(columns={'settle_date':'expiry'}),on='symbol',how='inner')
    df9['syear'] = df9.settle_date.astype(str).str.slice(0,4).astype(int)
    df9['smon'] = df9.settle_date.astype(str).str.slice(4,6).astype(int)
    df9['sday'] = df9.settle_date.astype(str).str.slice(6,8).astype(int)
    df9['eyear'] = df9.expiry.astype(str).str.slice(0,4).astype(int)
    df9['emon'] = df9.expiry.astype(str).str.slice(4,6).astype(int)
    df9['eday'] = df9.expiry.astype(str).str.slice(6,8).astype(int)
    df9['sdatetime'] = df9.apply(lambda r:datetime.datetime(r.syear,r.smon,r.sday),axis=1)
    df9['edatetime'] = df9.apply(lambda r:datetime.datetime(r.eyear,r.emon,r.eday),axis=1)
    df9['dte'] = df9.edatetime - df9.sdatetime
    df9.dte = df9.dte.dt.days
    df9 = df9[['symbol','settle_date','pc','contract_num','strike','close_x','close_y','dte']]
    df10 = df9.iloc[:len(df9)].copy()
    df10.index = list(range(len(df10)))
    if USE_PYVOL:
        df10['iv'] = df10.apply(lam_pyvol,axis=1)
    else:
        n = 100
        for i in tqdm_notebook(np.arange(0,len(df10)-n,n)):
                df10.loc[i:i+n,'iv'] = df10.loc[i:i+n].apply(lam_mibian,axis=1)
        print(f'doing remaining {datetime.datetime.now()}')
        i = df10[df10.iv.isna()].index[0]
        df10.loc[i:,'iv'] = df10.loc[i:].apply(lam_mbian,axis=1)
        print(f'done with remaining {datetime.datetime.now()}')
    return df10

# %% [markdown]
# #### example of using mibian for options calcs (we use py_vollib instead)

# %%
def _test_mibian():
    underlying=1.4565
    strike=1.45
    interest = 1
    days=30
    opt_info = [underlying,strike,interest,days]
    c = mibian.BS(opt_info, volatility=20)
    print(c.callPrice,
    c.putPrice,
    c.callDelta,
    c.putDelta,
    c.callDelta2,
    c.putDelta2,
    c.callTheta,
    c.putTheta,
    c.callRho,
    c.putRho,
    c.vega,
    c.gamma)


    co = mibian.BS(opt_info, callPrice=c.callPrice)
    co.impliedVolatility

# %% [markdown]
# #### Show simple example of using py_vol package

# %%
def _test_py_vollib():
    #CL,Q2019,560P,07/02/2019,0.6,1.61,0.54,1.54,1997,4465
    F = 56.25
    K = 56
    sigma = .366591539
    flag = 'p'
    t = 15/365.0
    r = .025
    discounted_call_price = black.black(flag, F, K, t, r, sigma)
    dcp = 1.54
    ivpy = implied_volatility.implied_volatility(dcp, F, K, r, t, flag)
    ivmn = mibian.BS([F,K,2.5,15], callPrice=dcp).impliedVolatility
    discounted_call_price,ivpy,ivmn

# %%
def plotly_plot(df_in,x_column,plot_title=None,
                y_left_label=None,y_right_label=None,
                bar_plot=False,figsize=(16,10),
                number_of_ticks_display=20,
                yaxis2_cols=None):
    ya2c = [] if yaxis2_cols is None else yaxis2_cols
    ycols = [c for c in df_in.columns.values if c != x_column]
    # create tdvals, which will have x axis labels
    td = list(df_in[x_column]) 
    nt = len(df_in)-1 if number_of_ticks_display > len(df_in) else number_of_ticks_display
    spacing = len(td)//nt
    tdvals = td[::spacing]
    
    # create data for graph
    data = []
    # iterate through all ycols to append to data that gets passed to go.Figure
    for ycol in ycols:
        if bar_plot:
            b = go.Bar(x=td,y=df_in[ycol],name=ycol,yaxis='y' if ycol not in ya2c else 'y2')
        else:
            b = go.Scatter(x=td,y=df_in[ycol],name=ycol,yaxis='y' if ycol not in ya2c else 'y2')
        data.append(b)

    # create a layout
    layout = go.Layout(
        title=plot_title,
        xaxis=dict(
            ticktext=tdvals,
            tickvals=tdvals,
            tickangle=45,
            type='category'),
        yaxis=dict(
            title='y main' if y_left_label is None else y_left_label
        ),
        yaxis2=dict(
            title='y alt' if y_right_label is None else y_right_label,
            overlaying='y',
            side='right'),
        margin=Margin(
            b=100
        )        
    )

    fig = go.Figure(data=data,layout=layout)
    return fig

# %% [markdown]
# #### Define method to get a contract from postgres

# %%
def _next_monthyear_code(contract):
    code_val = contract[-3]
    code_num = DICT_MONTH_NUMS[code_val]
    y = int(contract[-2:])
    if code_num+1>12:
        next_code_num = 1
        next_y = y + 1
    else:
        next_code_num = code_num+1
        next_y = y
    next_code_val = MONTH_CODES[next_code_num-1]
    next_contract = contract[0:-3] + next_code_val + '%02d' %(next_y)
    return next_contract

def get_postgres_data(contract,strike_divisor=None):
    '''
    Get options and underlying data for ONLY ONE CONTRACT
    '''
    osql = f"select * from {opttab} where symbol='{contract}';"
    dfo = pga.get_sql(osql)
    if len(dfo)<10:
        e = f'''
        get_postgres_data ERROR: not enough option data for contract {contract} 
        '''
        raise ValueError(e)
    num_settle_days = len(dfo.settle_date.unique())
    u_contract = contract
    for i in range(12):
        usql = f"select * from {futtab} where symbol='{u_contract}';"
        dfu = pga.get_sql(usql)
        if len(dfu) < num_settle_days:
            u_contract = _next_monthyear_code(u_contract)
            print(f'trying contract {u_contract}')
        else:
            break

    if len(dfu)< num_settle_days:
        e = f'''
        get_postgres_data ERROR: not enough underlying days found for options contract {contract} 
        where len(underlying) = {len(dfu)} and num_settle_days = {num_settle_days}
        '''
        raise ValueError(e)
    # Merge options and futures data
    dfu = dfu.rename(columns={'symbol':'u_symbol'})
    df = dfo.merge(dfu,how='inner',on=['settle_date'])
    # Get options expiration dates
    df_expiry_dates = dfo[['symbol','settle_date']].groupby('symbol',as_index=False).max()
    df_additions = df_expiry_dates_additions[df_expiry_dates_additions.symbol==contract]
    df_additions = df_additions[['symbol','yyyymmdd_option']].rename(columns={'yyyymmdd_option':'settle_date'})
    additional_symbols = df_additions.symbol.values
    df_expiry_dates = df_expiry_dates[~df_expiry_dates.symbol.isin(additional_symbols)]
    df_expiry_dates = df_expiry_dates.append(df_additions).sort_values('symbol').copy()
    if strike_divisor is not None:
        df.strike = df.strike/strike_divisor
    return df,df_expiry_dates

# %%
def _get_contract_number_from_symbol(symbol):
    c = symbol[0:2]
    if c in ['CL','CB','ES','GE','NG']:
        return 2
    return 2

# %% [markdown]
# ### Use py_vol to get options skews by percent in/out of the money (moneyness)

# %% [markdown]
# #### Add in even "amount in/out the money strikes, and interpolate their implied vols and skews

# %%
def get_even_moneyness_strikes(df10):
    # define amounts around the money which will help create strikes to add
    moneyness = np.arange(.7,1.4,.05).round(6)
    # define columns on which to execute groupby
#     gb_cols = ['symbol','settle_date','pc','contract_num','dte','close_y']
    gb_cols = ['symbol','settle_date','contract_num','dte','close_y']
    # define function used in groupby.apply to create strikes and iv's at those strikes
    #   where the strikes are an even amount from the money 
    #   (like .7, .8, ... 1, 1.1, 1.2, etc)
    def _add_even_moneyness_strikes(df):
        # get underlying from first row (the groupby makes them all the same)
        r = df.iloc[0]
        underlying = r.close_y
        # create new rows to append to df, using only the gb_cols
        df_ret1 = df.iloc[:len(moneyness)][gb_cols].copy()
        # add nan iv's !!!! MUST BE np.nan - NOT None
        df_ret1['iv'] = np.nan
        # add new strikes
        df_ret1['strike'] = moneyness * underlying
        # append the new strikes
        try:
            # try with using the sort=True options for versions of pandas after 0.23
            dfa = df.append(df_ret1,ignore_index=True,sort=True).copy()
        except:
            # otherwise do not specify sort
            dfa = df.append(df_ret1,ignore_index=True).copy()
        df_ret2 = dfa.sort_values(['symbol','settle_date','pc','strike'])
        df_ret2 = df_ret2.drop_duplicates(subset='strike')
        # set the index to the strike so that interpolate works
        df_ret2.index = df_ret2.strike
        # create interpolated iv's
        df_ret2['iv'] = df_ret2.iv.interpolate(method='polynomial', order=2)
        # reset the index
        df_ret2.index = list(range(len(df_ret2)))
        return df_ret2

    # start here
    df11 = df10.groupby(gb_cols).apply(_add_even_moneyness_strikes).copy()
    df11.index = list(range(len(df11)))
    df11['moneyness'] = df11.strike / df11.close_y
    df11.moneyness = df11.moneyness.round(4)

    df12 = df11[(df11.moneyness.isin(moneyness)) & (~df11.iv.isna())].copy()
    df12.moneyness  = df12.moneyness - 1
    df12.index = list(range(len(df12)))
    df12_atm = df12[df12.moneyness==0][['symbol','settle_date','pc','iv']]
    df12_atm = df12_atm.rename(columns={'iv':'atm_iv'})
    
    df12_atm = df12_atm.drop_duplicates()
    df12 = df12.merge(df12_atm,on=['symbol','settle_date','pc'],how='inner')
    df12.moneyness = df12.moneyness.round(4)
    df12['vol_skew'] = (df12.iv - df12.atm_iv).round(4)
    return df12

# %% [markdown]
# #### get all contracts in the options database

# %%
all_contracts = pga.get_sql(f"select distinct symbol from {opttab} where symbol~'^{SYMBOL_TO_RESEARCH}'").sort_values('symbol').values.reshape(-1)
len(all_contracts)
# Out:
# 84

# %% [markdown]
# #### show last dates

# %%
sql = f'''
select symbol, count(settle_date), max(settle_date) last_date from {opttab} 
where substring(symbol,1,2)='{SYMBOL_TO_RESEARCH}'
group by symbol
order by symbol;
'''
display.display(pga.get_sql(sql))
# Out:
#    symbol   count  last_date
# 0   ESF11    4915   20110121
# 1   ESF12   33360   20120120
# 2   ESF13   35838   20130118
# 3   ESF14   43294   20140117
# 4   ESF15   48975   20150116
# ..    ...     ...        ...
# 79  ESZ16  110971   20161216
# 80  ESZ17  130116   20171215
# 81  ESZ18  151372   20181221
# 82  ESZ19  139031   20191220
# 83  ESZ20     622   20191231
#
# [84 rows x 3 columns]

# %%
# symbol_to_search='CLG20'
# sql = f'''
# select distinct symbol, settle_date  from {opttab} 
# where symbol='{symbol_to_search}'
# order by settle_date desc;
# '''
# display.display(pga.get_sql(sql))

# %%
def create_skew_per_date_df(df):
    '''
    Find the first settle_date whose count of rows is equal to max count of rows.
    '''
    # get the first symbol (which should be the only symbol)
    contract = df.symbol.unique()[0]
    # get just that symbol's data
    df12 = df[df.symbol==contract]
    df_counts = df12[['settle_date','moneyness']].groupby('settle_date',as_index=False).count()
    max_count = df_counts.moneyness.max()
    first_max_count_settle_date = df_counts[df_counts.moneyness==max_count].iloc[0].settle_date
    
    df_ret = df12[df12.settle_date==first_max_count_settle_date][['moneyness']]
    all_settle_dates = sorted(df_counts.settle_date.unique())
    for settle_date in all_settle_dates:
        df_temp = df12[df12.settle_date==settle_date][['moneyness','vol_skew']]
        df_ret = df_ret.merge(df_temp,on='moneyness',how='outer')
        df_ret = df_ret.rename(columns={'vol_skew':str(settle_date)})
    df_ret = df_ret.sort_values('moneyness')
    return df_ret

# %% [markdown]
# ### Skew per contract

# %%
def skew_per_symbol(symbol,strike_divisor=None):
    '''
    For a symbol like CLM16 or EZH19, create 2 Dataframes
      1. df_iv - contains rows of implied vols, for only the 'pseudo' strikes that are an even
                 percent away from the money for each settle_date
      2. df_skew - contains one row per day of skew data of for 'pseudo' strikes that are an even
                 percent away from the money for each settle_date
    '''
    _exception = None
    _stacktrace = None
    df_iv = None
    df_skew = None
    try:
        df,df_expiry_dates = get_postgres_data(symbol)
        if len(df[df.contract_num==2])>0:
            df10 = get_implieds(df,df_expiry_dates,symbol)
            df12 = get_even_moneyness_strikes(df10)
            df_sk = create_skew_per_date_df(df12)
            df_skt = df_sk.T
            df_skt.columns = df_skt.loc['moneyness']
            df_skt = df_skt.iloc[1:].copy()
            df_skt['symbol'] = symbol
            df_skt['settle_date'] = df_skt.index
            df_iv = df12.copy() 
            df_skew = df_skt.copy()
    except Exception as e:
        _exception = str(e)
        _stacktrace = traceback.format_exc()
    return df_iv,df_skew,_exception,_stacktrace

# %%
all_contracts
# Out:
# array(['ESF11', 'ESF12', 'ESF13', 'ESF14', 'ESF15', 'ESF16', 'ESG11',
#        'ESG12', 'ESG13', 'ESG14', 'ESG15', 'ESG16', 'ESH11', 'ESH12',
#        'ESH13', 'ESH14', 'ESH15', 'ESH16', 'ESH17', 'ESH18', 'ESH19',
#        'ESH20', 'ESJ11', 'ESJ12', 'ESJ13', 'ESJ14', 'ESJ15', 'ESJ16',
#        'ESK11', 'ESK12', 'ESK13', 'ESK14', 'ESK15', 'ESK16', 'ESM11',
#        'ESM12', 'ESM13', 'ESM14', 'ESM15', 'ESM16', 'ESM17', 'ESM18',
#        'ESM19', 'ESM20', 'ESN11', 'ESN12', 'ESN13', 'ESN14', 'ESN15',
#        'ESQ11', 'ESQ12', 'ESQ13', 'ESQ14', 'ESQ15', 'ESU11', 'ESU12',
#        'ESU13', 'ESU14', 'ESU15', 'ESU16', 'ESU17', 'ESU18', 'ESU19',
#        'ESU20', 'ESV11', 'ESV12', 'ESV13', 'ESV14', 'ESV15', 'ESX11',
#        'ESX12', 'ESX13', 'ESX14', 'ESX15', 'ESZ11', 'ESZ12', 'ESZ13',
#        'ESZ14', 'ESZ15', 'ESZ16', 'ESZ17', 'ESZ18', 'ESZ19', 'ESZ20'],
#       dtype=object)

# %% [markdown]
# ## MAIN LOOP
# #### Loop through all contracts and create DataFrames for implied vol and skew (`df_iv_final` and `df_iv_skew`)

# %%
strike_div = None if SYMBOL_TO_RESEARCH not in STRIKE_DIVISORS.keys() else STRIKE_DIVISORS[SYMBOL_TO_RESEARCH]
df_iv_final = None
df_iv_skew = None
dict_exceptions = {}
dict_stacktraces = {}
contracts = all_contracts
if SYMBOL_TO_RESEARCH in ['ES','GE']:
    contracts = [c for c in all_contracts if c[-3] in ['H','M','U','Z']]
for contract in tqdm_notebook(contracts):
    df12,df_skew,_exception,_stacktrace = skew_per_symbol(contract,strike_divisor=strike_div)
    if _exception is not None:
        dict_exceptions[contract] = _exception
        dict_stacktraces[contract] = _stacktrace
        continue
    
    if (df12 is None or len(df12)<1) or (df_skew is None or len(df_skew)<1):
        if (df12 is None or len(df12)<1):
            dict_exceptions[contract] = "No data returned for df in skew_per_symbol"
        if (df_skew is None or len(df_skew)<1):
            dict_exceptions[contract] = "No data returned for df_skew in skew_per_symbol"
        continue
    if df12 is not None:
        if df_iv_final is None:
            df_iv_final = df12.copy()
        else:
            df_iv_final = df_iv_final.append(df12,ignore_index=True)
        if df_iv_skew is None:
            df_iv_skew = df_skew.copy()
        else:
            df_iv_skew = df_iv_skew.append(df_skew,ignore_index=True)
            df_iv_skew.index = list(range(len(df_iv_skew)))
df_iv_final = df_iv_final.sort_values(['settle_date','moneyness'])
# Out:
# HBox(children=(IntProgress(value=0, max=40), HTML(value='')))
# 2020-01-06 14:42:43,117 - numexpr.utils - INFO - NumExpr defaulting to 4 threads.

# %%
len(df_iv_final)
# Out:
# 28486

# %% [markdown]
# ### save to csv and print any exceptions that might have occured

# %%
print(dict_exceptions)
df_iv_final.to_csv(f'./temp_folder/df_iv_final_{SYMBOL_TO_RESEARCH}.csv',index=False)
df_iv_skew.to_csv(f'./temp_folder/df_iv_skew_{SYMBOL_TO_RESEARCH}.csv',index=False)
# Out:
# {'ESH11': 'No data returned for df_skew in skew_per_symbol', 'ESU20': 'No data returned for df_skew in skew_per_symbol', 'ESZ20': 'No data returned for df_skew in skew_per_symbol'}

# %% [markdown]
# ### graph skew

# %%
def graph_skew(df,do_plot=False):
    '''
    Graph skew for ONLY ONE symbol.
    If df contains more than one symbol, we will only graph the first symbol in the DataFrames    
    '''
    # get the first symbol (which should be the only symbol)
    contract = df.symbol.unique()[0]
    dfp = create_skew_per_date_df(df_iv_final[df_iv_final.symbol==contract])
    
#     display.display(dfp)
    settle_dates = sorted([c for c in dfp.columns.values if c != 'moneyness'])
    splits = list(np.arange(5,len(settle_dates),5))
#     settle_date_strings = [str(yyyymmdd) for yyyymmdd in settle_dates]
    settle_date_groups = np.split(np.array(settle_dates),splits)
    ret_figs = []
    for sdg in settle_date_groups:
        sdg_sorted = [str(c) for c in sorted(sdg)]
        cols = ['moneyness']+list(sdg_sorted)
        dfp_sub = dfp[cols]
        t = f'{contract} {sdg[0]} - {sdg[-1]}' 
        f = plotly_plot(dfp_sub,x_column='moneyness',plot_title=t,y_left_label='vol skew')
        ret_figs.append(f)
        if do_plot:
            iplot(f)
    return ret_figs

# %% [markdown]
# #### Do the same plots as above, but using a grid

# %%
def graph_skew_subplots(df):
    rfs = graph_skew(df)
    n = 4   
    # using list comprehension 
    rfs_groups = [rfs[i*n:(i + 1)*n] for i in range((len(rfs) + n - 1) // n )]  
    for rfs_group in rfs_groups:
        iplot(graph_skew_subplot_quad(rfs_group))
    
def graph_skew_subplot_quad(rfs):
    '''
    Use subplots to output the results of the method graph_skew above
    '''
    rows = 2#len(rfs)//2
    f1 = tls.make_subplots(rows=rows, cols=2,  
        shared_yaxes=False, 
        subplot_titles=[rfs[i]['layout'].title for i in range(len(rfs))],
        horizontal_spacing=0.09,
        vertical_spacing=0.11,                       
        print_grid=False)

    pl_width=900
    pl_height=800 
    title = 'Skew plots<br>'

    f1['layout'].update(title=title,                                 
        font= Font(family="Open Sans, sans-serif"),
        showlegend=True,     
        hovermode='x',  
        autosize=True,       
        width=pl_width,       
        height=pl_height,
        plot_bgcolor='#EFECEA', 
        bargap=0.05,
        margin=Margin(
                      l=45,
                      r=15,
                      b=55,
                      t=50
        )
    )    
    for i in range(len(rfs)):
        x = int(i/2) + 1
        y = i % 2 + 1
        f = rfs[i]
        l = f.layout
        
        try:
            yaxis = f'yaxis{i+1}'
            xaxis = f'xaxis{i+1}'
            if i < 10:
                yaxis = yaxis.replace('1','') 
                xaxis = xaxis.replace('1','') 
            f1['layout'].update({xaxis:l.xaxis})
            f1['layout'].update({yaxis:l.yaxis})
            gname = f'chart {x,y}'#rfs[i]['layout'].title
            for d in f.data:
                data_y = f'y{i+1}'.replace('1','') 
                d['yaxis']=data_y
                d['legendgroup'] =  gname
                d['name'] = f"{gname} {d.name}"
                f1.append_trace(d,x,y)
            pass
        except Exception as e:
            ipdb.set_trace()
            print(f'graph_skew_subplots ERRORS: {str(e)}')
    return f1
# iplot(f1)

# %%
df_ivf2 = df_iv_final[df_iv_final.symbol.str.contains(f'{SYMBOL_TO_RESEARCH}')]
df_ivf2.sort_values(['settle_date','symbol','dte','strike'],ascending=False).head()
# Out:
#        close_x  close_y  contract_num  dte        iv   pc  settle_date  \
# 13994      NaN   3231.0             2  171  0.119227  NaN     20191231
# 13993      NaN   3231.0             2  171  0.112740  NaN     20191231
# 13992      NaN   3231.0             2  171  0.106949  NaN     20191231
# 13991      NaN   3231.0             2  171  0.104271  NaN     20191231
# 13990      NaN   3231.0             2  171  0.113935  NaN     20191231
#
#         strike symbol  moneyness    atm_iv  vol_skew
# 13994  4038.75  ESM20       0.25  0.140598   -0.0214
# 13993  3877.20  ESM20       0.20  0.140598   -0.0279
# 13992  3715.65  ESM20       0.15  0.140598   -0.0336
# 13991  3554.10  ESM20       0.10  0.140598   -0.0363
# 13990  3392.55  ESM20       0.05  0.140598   -0.0267

# %%
mcs = {'F':1,'G':2,'H':3,'J':4,'K':5,'M':6,'N':7,'Q':8,'U':9,'V':10,'X':11,'Z':12}
# sorted(list(set(df_iv_final.symbol)))
sorted([f'{s[:2]}{(2000+int(s[-2:]))*100 + int(mcs[s[-3]])}' for s in set(df_iv_final.symbol)])
# Out:
# ['ES201106',
#  'ES201109',
#  'ES201112',
#  'ES201203',
#  'ES201206',
#  'ES201209',
#  'ES201212',
#  'ES201303',
#  'ES201306',
#  'ES201309',
#  'ES201312',
#  'ES201403',
#  'ES201406',
#  'ES201409',
#  'ES201412',
#  'ES201503',
#  'ES201506',
#  'ES201509',
#  'ES201512',
#  'ES201603',
#  'ES201606',
#  'ES201609',
#  'ES201612',
#  'ES201703',
#  'ES201706',
#  'ES201709',
#  'ES201712',
#  'ES201803',
#  'ES201806',
#  'ES201809',
#  'ES201812',
#  'ES201903',
#  'ES201906',
#  'ES201909',
#  'ES201912',
#  'ES202003',
#  'ES202006']

# %%
grid_plot=True
# clist = [c for c in all_contracts if (c[:2]==f'{SYMBOL_TO_RESEARCH}') & (int(c[-2:])>=19)]
clist = [c for c in df_iv_final.symbol.unique() if (c[:2]==f'{SYMBOL_TO_RESEARCH}') & (int(c[-2:])>=19)]
for c in clist:
    dft = df_iv_final[df_iv_final.symbol==c]
    if len(dft)<=0:
        print(f'no data for symbol {c}')
        continue
    if grid_plot:
        graph_skew_subplots(df_iv_final[df_iv_final.symbol==c])
    else:
        rls = graph_skew(df_iv_final[df_iv_final.symbol==c],do_plot=True)
# Out:
# <div id="2535d1af-b876-47f8-99f4-b72bd794d5fa" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2535d1af-b876-47f8-99f4-b72bd794d5fa", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20180924", "uid": "24e202ae-30bd-11ea-8184-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1635, 0.1353, 0.1089, 0.0826, 0.0554, 0.0281, 0.0, -0.0244, -0.0296, -0.0167, -0.0013, 0.0109, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20180925", "uid": "24e27a06-30bd-11ea-a271-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, null, null, null, null, null, 0.0, null, null, null, null, null, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20180926", "uid": "24e2dcba-30bd-11ea-80fe-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1628, 0.1362, 0.1087, 0.0821, 0.0553, 0.028, 0.0, -0.0241, -0.0296, -0.0177, -0.0029, 0.0089, 0.0197, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20180927", "uid": "24e33e62-30bd-11ea-bf5f-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.165, 0.1368, 0.1108, 0.0828, 0.056, 0.0286, 0.0, -0.0245, -0.03, -0.017, -0.0023, 0.0095, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20180928", "uid": "24e3ad0c-30bd-11ea-9d35-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1657, 0.1382, 0.1112, 0.0832, 0.0563, 0.0284, 0.0, -0.0245, -0.0295, -0.0165, -0.0022, 0.0101, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181001", "uid": "24e48b46-30bd-11ea-be7b-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1673, 0.1381, 0.1114, 0.0842, 0.0566, 0.0284, 0.0, -0.0236, -0.0278, -0.0144, 0.0005, 0.0133, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181002", "uid": "24e50878-30bd-11ea-98ce-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.167, 0.1393, 0.112, 0.085, 0.0569, 0.0286, 0.0, -0.0235, -0.0291, -0.0162, -0.0016, 0.0114, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181003", "uid": "24e56cdc-30bd-11ea-8a81-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1659, 0.1373, 0.1111, 0.0831, 0.0559, 0.0279, 0.0, -0.0245, -0.0295, -0.0163, -0.0018, 0.0101, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181004", "uid": "24e5cdb4-30bd-11ea-9c84-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1658, 0.14, 0.1114, 0.0845, 0.0571, 0.029, 0.0, -0.0265, -0.0339, -0.0216, -0.0061, 0.0078, 0.0177, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181005", "uid": "24e6389c-30bd-11ea-a73a-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1671, 0.1403, 0.1127, 0.0853, 0.0577, 0.0294, 0.0, -0.0269, -0.0358, -0.0251, -0.0105, 0.001, 0.011, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (2, 1)", "name":  ...
# <div id="dabf3bca-f9c7-4b6c-8508-348dadb60bbf" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dabf3bca-f9c7-4b6c-8508-348dadb60bbf", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181022", "uid": "24f6bbcc-30bd-11ea-80cd-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1671, 0.1389, 0.1112, 0.0843, 0.0568, 0.029, 0.0, -0.0271, -0.0431, -0.0401, -0.0305, -0.0205, -0.0104, 0.0007], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181023", "uid": "24f7364c-30bd-11ea-9c08-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1651, 0.1365, 0.1101, 0.0831, 0.056, 0.0286, 0.0, -0.0259, -0.0408, -0.0382, -0.0283, -0.0177, -0.006, 0.0037], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181024", "uid": "24f7efe2-30bd-11ea-acbf-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1623, 0.1348, 0.107, 0.0806, 0.054, 0.0274, 0.0, -0.0252, -0.0436, -0.0466, -0.0383, -0.0288, -0.0161, -0.0038], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181025", "uid": "24f8b436-30bd-11ea-9d90-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, null, null, null, null, null, 0.0, null, null, null, null, null, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181026", "uid": "24f99b4c-30bd-11ea-bef3-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1632, 0.1347, 0.1071, 0.0808, 0.054, 0.0271, 0.0, -0.0249, -0.0419, -0.0461, -0.0398, -0.0301, -0.0217, -0.0113], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181029", "uid": "24fb1818-30bd-11ea-be63-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1617, 0.1337, 0.1064, 0.0799, 0.0531, 0.027, 0.0, -0.0255, -0.0432, -0.0456, -0.0404, -0.0327, -0.0227, -0.013], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181030", "uid": "24fb8a26-30bd-11ea-ab85-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1603, 0.1313, 0.1052, 0.0794, 0.0523, 0.0269, 0.0, -0.025, -0.0425, -0.0466, -0.0403, -0.0312, -0.0231, -0.0134], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181031", "uid": "24fbff24-30bd-11ea-9d72-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1576, 0.1291, 0.104, 0.0776, 0.0523, 0.0261, 0.0, -0.0245, -0.0393, -0.0423, -0.034, -0.0239, -0.013, -0.0003], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181101", "uid": "24fc7268-30bd-11ea-bdbd-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1573, 0.1319, 0.1052, 0.0793, 0.0534, 0.0275, 0.0, -0.0248, -0.0399, -0.0402, -0.0316, -0.0196, -0.0088, 0.0041], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181102", "uid": "24fcef2e-30bd-11ea-a6bf-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1527, 0.1283, 0.103, 0.0779, 0.0524, 0.0269, 0.0, -0.0253, -0.0415, -0.0424, -0.0338, -0.0231, -0.0123, 0.0015], "yaxis": "y2", "type": "scatter", " ...
# <div id="e83e2630-4cf4-484c-8ce3-c0bb1b23d8c5" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e83e2630-4cf4-484c-8ce3-c0bb1b23d8c5", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181119", "uid": "250f609e-30bd-11ea-afcd-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1593, 0.1327, 0.1074, 0.0812, 0.0554, 0.0283, 0.0, -0.0295, -0.0485, -0.0471, -0.0347, -0.0229, -0.0094, 0.0028], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181120", "uid": "250fd792-30bd-11ea-8fec-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1557, 0.1307, 0.1048, 0.0795, 0.0542, 0.0275, 0.0, -0.0291, -0.0507, -0.0546, -0.0457, -0.0331, -0.0203, -0.0111], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181121", "uid": "25106006-30bd-11ea-83cc-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1564, 0.1318, 0.1062, 0.0807, 0.0549, 0.0277, 0.0, -0.0283, -0.0485, -0.0505, -0.0393, -0.0293, -0.0144, -0.0016], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181123", "uid": "2510d79e-30bd-11ea-b330-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1575, 0.1316, 0.1067, 0.0811, 0.0556, 0.0285, 0.0, -0.0277, -0.0465, -0.0503, -0.0411, -0.0286, -0.0164, -0.0034], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181126", "uid": "25119a00-30bd-11ea-9d37-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1586, 0.1313, 0.1058, 0.0801, 0.0544, 0.0278, 0.0, -0.0275, -0.0438, -0.0431, -0.0318, -0.0165, -0.0007, 0.0119], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181127", "uid": "2513373e-30bd-11ea-9f08-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1585, 0.1313, 0.1056, 0.08, 0.0547, 0.028, 0.0, -0.0272, -0.0432, -0.0418, -0.0286, -0.0122, -0.0007, 0.0066], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181128", "uid": "2514041e-30bd-11ea-aedf-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1615, 0.1328, 0.1061, 0.0809, 0.0548, 0.0279, 0.0, -0.0253, -0.0392, -0.0361, -0.0208, -0.0034, 0.0056, 0.0158], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181129", "uid": "2514c95a-30bd-11ea-ba63-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1657, 0.1379, 0.1107, 0.084, 0.0565, 0.0289, 0.0, -0.027, -0.0415, -0.0377, -0.0229, -0.0068, 0.0049, 0.0188], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181130", "uid": "25159010-30bd-11ea-abbd-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1659, 0.1367, 0.1105, 0.085, 0.0577, 0.0294, 0.0, -0.0279, -0.0428, -0.0376, -0.0217, -0.0036, 0.0083, 0.0184], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20181203", "uid": "25162d90-30bd-11ea-bf8f-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1759, 0.1464, 0.1176, 0.0886, 0.0613, 0.0323, 0.0, -0.0278, -0.0386, -0.0281, -0.0103, 0.0061, 0.0181, 0.0255], "ya ...
# <div id="ce919810-2705-4d5c-b7c6-55ce5f7ae822" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ce919810-2705-4d5c-b7c6-55ce5f7ae822", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181219", "uid": "2527c74c-30bd-11ea-90d1-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1655, 0.1355, 0.1052, 0.0766, 0.0498, 0.0249, 0.0, -0.023, -0.0396, -0.0449, -0.0443, -0.0375, -0.0231, -0.0184], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181220", "uid": "25283de6-30bd-11ea-9036-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1676, 0.1365, 0.1058, 0.0777, 0.0507, 0.0245, 0.0, -0.0229, -0.0396, -0.0464, -0.048, -0.0427, -0.0347, -0.0286], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181221", "uid": "25291c28-30bd-11ea-8b03-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, 0.1363, 0.105, 0.0752, 0.0497, 0.0241, 0.0, -0.0229, -0.0419, -0.0499, -0.0484, -0.0434, -0.0399, -0.0267], "yaxis": "y", "type": "scatter", "xaxis": "x"}], {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "ESH19 20181219 - 20181221", "x": 0.2275, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "xaxis": {"anchor": "y", "domain": [0.0, 0.455], "tickangle": 45, "ticktext": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "tickvals": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "type": "category"}, "yaxis": {"anchor": "x", "domain": [0.555, 1.0], "title": "vol skew"}, "xaxis2": {"anchor": "y2", "domain": [0.545, 1.0]}, "yaxis2": {"anchor": "x2", "domain": [0.555, 1.0]}, "xaxis3": {"anchor": "y3", "domain": [0.0, 0.455]}, "yaxis3": {"anchor": "x3", "domain": [0.0, 0.445]}, "xaxis4": {"anchor": "y4", "domain": [0.545, 1.0]}, "yaxis4": {"anchor": "x4", "domain": [0.0, 0.445]}, "font": {"family": "Open Sans, sans-serif"}, "margin": {"b": 55, "l": 45, "r": 15, "t": 50}, "title": "Skew plots<br>", "showlegend": true, "hovermode": "x", "autosize": true, "width": 900, "height": 800, "plot_bgcolor": "#EFECEA", "bargap": 0.05}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="6dd2e6ee-2cb7-41ee-a34a-e01a8d60ea94" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6dd2e6ee-2cb7-41ee-a34a-e01a8d60ea94", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181224", "uid": "25e83b34-30bd-11ea-ae98-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, 0.094, 0.0719, 0.0554, 0.037, 0.0183, 0.0, -0.0176, -0.0331, -0.0445, -0.0515, -0.0547, -0.0529, -0.055], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181226", "uid": "25e8a55e-30bd-11ea-8fd9-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1118, 0.0915, 0.0727, 0.0549, 0.0368, 0.0182, 0.0, -0.0173, -0.0318, -0.0429, -0.0487, -0.051, -0.0497, -0.0475], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181227", "uid": "25e90fee-30bd-11ea-8ce5-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.113, 0.0944, 0.0753, 0.0571, 0.0385, 0.0185, 0.0, -0.0167, -0.0313, -0.0415, -0.0474, -0.0502, -0.049, -0.045], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181228", "uid": "25e9a648-30bd-11ea-9afa-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1159, 0.0949, 0.0763, 0.0577, 0.0388, 0.0193, 0.0, -0.0178, -0.0327, -0.0423, -0.0469, -0.0475, -0.0454, -0.04], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20181231", "uid": "25ea294c-30bd-11ea-9e48-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1166, 0.0952, 0.0768, 0.0584, 0.0402, 0.02, 0.0, -0.0189, -0.0336, -0.0424, -0.0452, -0.0426, -0.0395, -0.0347], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190102", "uid": "25eb2a22-30bd-11ea-aec2-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1159, 0.0959, 0.0775, 0.0583, 0.0392, 0.0197, 0.0, -0.0182, -0.0331, -0.0424, -0.0451, -0.0419, -0.0345, -0.0278], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190103", "uid": "25eb96f6-30bd-11ea-ada7-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1083, 0.0902, 0.0727, 0.0548, 0.0379, 0.019, 0.0, -0.0184, -0.034, -0.0474, -0.0541, -0.0539, -0.0505, -0.041], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190104", "uid": "25ebf9ac-30bd-11ea-9a7a-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1091, 0.0912, 0.0745, 0.0563, 0.038, 0.0191, 0.0, -0.0183, -0.0353, -0.0469, -0.0507, -0.0471, -0.038, -0.0297], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190107", "uid": "25ec5c62-30bd-11ea-b0e0-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, null, null, null, null, null, 0.0, null, null, null, null, null, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190108", "uid": "25ecc8e6-30bd-11ea-8387-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1162, 0.0973, 0.0785, 0.0601, 0.0408, 0.0206, 0.0, -0.0199, -0.0373, -0.0489, -0.0516, -0.0463, -0.0326, -0.0256], "yaxis": "y2", "type": "scatter", "x ...
# <div id="4c6851e6-8ddf-4e94-bf7c-292bc5893749" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4c6851e6-8ddf-4e94-bf7c-292bc5893749", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190124", "uid": "25fc9082-30bd-11ea-beae-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1466, 0.1219, 0.0982, 0.0751, 0.0513, 0.0261, 0.0, -0.0232, -0.0408, -0.043, -0.033, -0.0205, -0.008, 0.0007], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190125", "uid": "25fd1f66-30bd-11ea-b8ff-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1424, 0.1192, 0.0961, 0.0731, 0.0496, 0.0245, 0.0, -0.0235, -0.0395, -0.041, -0.031, -0.0179, -0.0052, 0.0061], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190128", "uid": "25fd8a9e-30bd-11ea-b455-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1422, 0.1194, 0.0959, 0.0739, 0.0499, 0.0251, 0.0, -0.0237, -0.0408, -0.0431, -0.032, -0.019, -0.0065, 0.0033], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190129", "uid": "25fdfe5e-30bd-11ea-8563-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1426, 0.1193, 0.0958, 0.0727, 0.0496, 0.0256, 0.0, -0.0239, -0.0413, -0.0425, -0.0322, -0.0196, -0.0058, 0.001], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190130", "uid": "25fe68e4-30bd-11ea-beb1-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1458, 0.1205, 0.0965, 0.0738, 0.0491, 0.025, 0.0, -0.023, -0.0387, -0.0371, -0.025, -0.0118, -0.002, 0.0037], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190131", "uid": "25ff681e-30bd-11ea-a6f5-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1488, 0.1234, 0.0976, 0.0735, 0.0488, 0.0243, 0.0, -0.0225, -0.0356, -0.0338, -0.0203, -0.0068, 0.0043, 0.0099], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190201", "uid": "26000746-30bd-11ea-838a-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1483, 0.123, 0.0984, 0.0739, 0.0495, 0.0246, 0.0, -0.022, -0.0343, -0.0313, -0.019, -0.0063, 0.0019, 0.0126], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190204", "uid": "26007da8-30bd-11ea-b235-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1517, 0.1244, 0.0997, 0.075, 0.0498, 0.0252, 0.0, -0.0216, -0.0323, -0.027, -0.0138, -0.001, 0.0106, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190205", "uid": "2600e8da-30bd-11ea-ad8c-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1525, 0.1263, 0.1003, 0.0756, 0.0507, 0.0255, 0.0, -0.0215, -0.0325, -0.027, -0.0133, -0.0007, 0.0121, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190206", "uid": "260184de-30bd-11ea-a0f5-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1523, 0.1259, 0.1015, 0.0753, 0.0505, 0.0256, 0.0, -0.0223, -0.0326, -0.0278, -0.0137, -0.0027, 0.0109, null], "yaxis": "y2", "type": "s ...
# <div id="96dfefe8-b198-4c41-84e2-9a00502e359d" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("96dfefe8-b198-4c41-84e2-9a00502e359d", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190222", "uid": "2611432e-30bd-11ea-8e08-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1677, 0.1386, 0.111, 0.0837, 0.0557, 0.0285, 0.0, -0.0252, -0.0302, -0.0151, 0.0011, 0.013, 0.0216, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190225", "uid": "2611e2de-30bd-11ea-ac71-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1737, 0.144, 0.1155, 0.0867, 0.0584, 0.03, 0.0, -0.0254, -0.0303, -0.0151, 0.002, 0.016, 0.0238, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190226", "uid": "26125408-30bd-11ea-93ec-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1749, 0.1459, 0.1165, 0.0878, 0.0594, 0.0307, 0.0, -0.0262, -0.0323, -0.0173, -0.0008, 0.0144, 0.0243, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190227", "uid": "2612ca64-30bd-11ea-8267-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1742, 0.1438, 0.1152, 0.0869, 0.0586, 0.0303, 0.0, -0.0275, -0.0323, -0.0167, -0.0001, 0.0111, 0.0143, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190228", "uid": "26135452-30bd-11ea-80ab-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, null, null, null, null, null, 0.0, null, null, null, null, null, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190301", "uid": "2614abcc-30bd-11ea-81ad-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1793, 0.1483, 0.1197, 0.0905, 0.0622, 0.032, 0.0, -0.0279, -0.0275, -0.0091, 0.0069, 0.0179, 0.0228, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190304", "uid": "26155ac2-30bd-11ea-a5bc-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1799, 0.1495, 0.1201, 0.0911, 0.0616, 0.0325, 0.0, -0.0294, -0.0303, -0.0104, 0.0074, 0.0186, 0.0277, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190305", "uid": "2615f3b0-30bd-11ea-8869-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1834, 0.1522, 0.1214, 0.0924, 0.0635, 0.0327, 0.0, -0.0295, -0.0296, -0.0103, 0.0066, 0.0159, 0.0191, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190306", "uid": "261666b0-30bd-11ea-8e30-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1797, 0.1488, 0.12, 0.0914, 0.0625, 0.0332, 0.0, -0.0312, -0.0339, -0.0135, 0.0044, 0.0137, 0.0199, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190307", "uid": "2616d62c-30bd-11ea-b283-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, null, null, null, null, null, 0.0, null, null, null, null, null, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (2, 1)", "name": "chart (2, 1) 201 ...
# <div id="899faec0-db25-47a6-8310-0c0e765834d7" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("899faec0-db25-47a6-8310-0c0e765834d7", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190318", "uid": "26e9de28-30bd-11ea-935c-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1333, 0.1112, 0.0903, 0.0688, 0.0471, 0.0242, 0.0, -0.0234, -0.0344, -0.0287, -0.0176, -0.0064, 0.0016, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190319", "uid": "26ea4234-30bd-11ea-a18d-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1364, 0.1123, 0.0915, 0.07, 0.0475, 0.0245, 0.0, -0.0234, -0.0344, -0.0302, -0.0198, -0.0084, -0.0012, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190320", "uid": "26eac2f4-30bd-11ea-a15a-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1361, 0.1121, 0.0917, 0.0694, 0.0471, 0.0246, 0.0, -0.0235, -0.0352, -0.0315, -0.0227, null, -0.0017, -0.0002], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190321", "uid": "26eb2ccc-30bd-11ea-8a5a-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1362, 0.1145, 0.0928, 0.0701, 0.0477, 0.0246, 0.0, -0.0233, -0.0343, -0.0302, -0.0215, -0.0096, -0.0026, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190322", "uid": "26eb8f0c-30bd-11ea-984c-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1349, 0.1121, 0.0914, 0.0697, 0.0472, 0.0244, 0.0, -0.0252, -0.041, -0.0399, -0.034, -0.0254, -0.0191, -0.0175], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190325", "uid": "26ec9bf4-30bd-11ea-a38c-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.132, 0.1111, 0.09, 0.0689, 0.0467, 0.0244, 0.0, -0.0249, -0.0406, -0.0414, -0.0357, -0.0263, -0.0154, -0.0046], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190326", "uid": "26ed2fcc-30bd-11ea-87a7-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1342, 0.1126, 0.0913, 0.0702, 0.0478, 0.0248, 0.0, -0.0249, -0.0404, -0.0382, -0.031, -0.0219, -0.0118, -0.0045], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190327", "uid": "26edbd06-30bd-11ea-a5f2-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1323, 0.1117, 0.0907, 0.0689, 0.0473, 0.0245, 0.0, -0.0249, -0.0405, -0.0393, -0.032, -0.0241, -0.0127, -0.0016], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190328", "uid": "26ee23ca-30bd-11ea-ac73-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1318, 0.1111, 0.0915, 0.0698, 0.048, 0.0252, 0.0, -0.0256, -0.0398, -0.0364, -0.0284, -0.0204, -0.0143, -0.0118], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190329", "uid": "26ee8fc2-30bd-11ea-a02b-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1345, 0.1136, 0.0921, 0.0705, 0.0487, 0.0254, 0.0, -0.0251, -0.0387, -0.034, -0.0264, -0.0197, -0.0101, null], "yaxis": "y2 ...
# <div id="a94b1ae1-13c0-4fc4-a28f-0e78b181363a" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a94b1ae1-13c0-4fc4-a28f-0e78b181363a", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190415", "uid": "26fe6d34-30bd-11ea-93c9-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, null, null, null, null, null, 0.0, null, null, null, null, null, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190416", "uid": "26fee658-30bd-11ea-adfe-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1517, 0.1262, 0.1021, 0.0776, 0.053, 0.0272, 0.0, -0.0239, -0.0301, -0.0209, -0.0079, 0.0041, 0.0173, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190417", "uid": "26ff6838-30bd-11ea-8d0f-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1526, 0.1268, 0.1021, 0.0778, 0.0532, 0.0275, 0.0, -0.0248, -0.0314, -0.0216, -0.0079, 0.005, 0.0152, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190418", "uid": "26ffe39e-30bd-11ea-a898-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1532, 0.1287, 0.1023, 0.078, 0.0532, 0.0274, 0.0, -0.0247, -0.0309, -0.0207, -0.0077, 0.0042, 0.0176, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190422", "uid": "270059be-30bd-11ea-bbbc-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1588, 0.1333, 0.1069, 0.0822, 0.0561, 0.0289, 0.0, -0.025, -0.0304, -0.0194, -0.0063, 0.0053, 0.0134, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190423", "uid": "2701ea74-30bd-11ea-8704-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1631, 0.1355, 0.1106, 0.084, 0.0576, 0.0292, 0.0, -0.024, -0.0278, -0.017, -0.0047, 0.0085, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190424", "uid": "27025dc2-30bd-11ea-826e-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1626, 0.1373, 0.1108, 0.0841, 0.0577, 0.0296, 0.0, -0.0243, -0.0294, -0.0193, -0.0062, 0.0065, 0.0178, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190425", "uid": "2702c81e-30bd-11ea-9cdf-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1626, 0.1362, 0.1103, 0.0844, 0.0576, 0.0297, 0.0, -0.0251, -0.0297, -0.0205, -0.0085, 0.0039, 0.0173, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190426", "uid": "27034098-30bd-11ea-89df-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1645, 0.1384, 0.1113, 0.0845, 0.0579, 0.0299, 0.0, -0.0246, -0.0277, -0.0164, -0.003, 0.0096, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190429", "uid": "2703c086-30bd-11ea-b358-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1672, 0.1396, 0.1122, 0.0857, 0.0581, 0.0298, 0.0, -0.0251, -0.0288, -0.0176, -0.0033, 0.0092, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (2,  ...
# <div id="21be9842-2361-4473-8229-e7857adf615d" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("21be9842-2361-4473-8229-e7857adf615d", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190514", "uid": "2715590c-30bd-11ea-8f7d-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1559, 0.1285, null, 0.0792, 0.0545, 0.0285, 0.0, -0.0297, -0.0431, -0.038, -0.0277, -0.0154, -0.0014, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190515", "uid": "2715ca24-30bd-11ea-9638-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1583, 0.1296, 0.104, 0.0802, 0.0551, 0.0288, 0.0, -0.0293, -0.0403, -0.0329, -0.0208, -0.0085, 0.0058, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190516", "uid": "27163ca2-30bd-11ea-8507-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1629, 0.1327, 0.1071, 0.0815, 0.0555, 0.029, 0.0, -0.0274, -0.0351, -0.0265, -0.0147, -0.0012, 0.0128, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190517", "uid": "2716da86-30bd-11ea-8c7f-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1602, 0.1325, 0.1068, 0.0819, 0.0559, 0.0293, 0.0, -0.0289, -0.0379, -0.0293, -0.0159, -0.0021, 0.0102, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190520", "uid": "2717513a-30bd-11ea-8163-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1582, 0.1293, 0.1053, 0.0807, 0.055, 0.0289, 0.0, -0.0286, -0.039, -0.0314, -0.0165, -0.0055, 0.0081, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190521", "uid": "27187c4c-30bd-11ea-ac5c-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1628, 0.1321, 0.1058, 0.0811, 0.0555, 0.0285, 0.0, -0.0276, -0.0351, -0.0265, -0.0123, 0.0004, 0.0105, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190522", "uid": "2718e6d2-30bd-11ea-9f42-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1626, 0.1341, 0.1076, 0.0809, 0.056, 0.0293, 0.0, -0.0286, -0.0358, -0.0267, -0.0134, -0.0004, 0.0044, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190523", "uid": "271979e4-30bd-11ea-8eff-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1561, 0.1262, 0.1024, 0.0788, 0.0542, 0.0282, 0.0, -0.0292, -0.0413, -0.0347, -0.023, null, -0.0085, 0.0102], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190524", "uid": "2719f626-30bd-11ea-82b7-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1543, 0.1268, 0.1016, 0.0782, 0.0547, 0.0288, 0.0, -0.029, -0.04, -0.0327, -0.0204, -0.0114, -0.0038, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190528", "uid": "271a70e2-30bd-11ea-be96-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1504, 0.1235, 0.0994, 0.0767, 0.0527, 0.0273, 0.0, -0.029, -0.0424, -0.0377, -0.0273, -0.0135, -0.0092, 0.0099], "yaxis": "y2", "type": "scatter",  ...
# <div id="0dbcca0a-882c-48d9-b151-bb858c4cc40b" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0dbcca0a-882c-48d9-b151-bb858c4cc40b", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190612", "uid": "272c5c12-30bd-11ea-a675-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, null, null, null, null, null, 0.0, null, null, null, null, null, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190613", "uid": "272d4212-30bd-11ea-9aa6-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1697, 0.1394, 0.1126, 0.0858, 0.0585, 0.0308, 0.0, -0.0281, -0.0344, -0.0259, -0.0154, 0.0005, 0.014, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190614", "uid": "272dfa54-30bd-11ea-a8d9-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1673, 0.1384, 0.1105, 0.0853, 0.0583, 0.0305, 0.0, -0.0286, -0.034, -0.0256, -0.0136, 0.0023, 0.016, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190617", "uid": "272edb22-30bd-11ea-945d-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1697, 0.1397, 0.1136, 0.0858, 0.0591, 0.0315, 0.0, -0.0279, -0.0338, -0.025, -0.0148, 0.0048, 0.0189, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190618", "uid": "272f5e4c-30bd-11ea-b801-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1743, 0.1438, 0.1153, 0.0877, 0.0603, 0.0318, 0.0, -0.027, -0.0307, -0.0228, -0.0082, 0.0082, 0.0221, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190619", "uid": "27305876-30bd-11ea-8570-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1779, 0.1483, 0.1182, 0.0897, 0.0609, 0.0322, 0.0, -0.0257, -0.0277, -0.0178, -0.0028, 0.0134, 0.0275, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190620", "uid": "2730c018-30bd-11ea-bf53-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [null, null, null, null, null, null, 0.0, null, null, null, null, 0.0146, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190621", "uid": "27312ee8-30bd-11ea-a173-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1792, 0.1471, 0.1183, 0.0893, 0.0605, 0.0307, 0.0, -0.0252, -0.028, -0.0178, -0.0039, 0.0091, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}], {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "ESU19 20190612 - 20190618", "x": 0.2275, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "ESU19 20190619 - 20190621", "x": 0.7725, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "xaxis": {"anchor": "y", "domain": [0.0, 0.455], "tickangle": 45, "ticktext": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "tickvals": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "type": "category"}, "yaxis": {"anchor": "x", "domain": [0.555, 1.0], "title": "vol skew"}, "xaxis2": {"anchor": "y2", "domain": [0.545, 1.0], "tick ...
# <div id="e82f705d-c75a-49b3-81b9-14cd05af8549" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e82f705d-c75a-49b3-81b9-14cd05af8549", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190624", "uid": "27eef2c2-30bd-11ea-abb4-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1343, 0.1122, 0.0915, 0.0699, 0.0477, 0.0246, 0.0, -0.023, -0.0335, -0.0291, -0.0218, -0.0142, -0.0048, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190625", "uid": "27ef893a-30bd-11ea-9700-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1326, 0.1123, 0.0899, 0.0697, 0.0476, 0.0249, 0.0, -0.023, -0.036, -0.0329, -0.0257, -0.0169, -0.0088, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190626", "uid": "27eff640-30bd-11ea-99aa-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1321, 0.1122, 0.091, 0.0699, 0.0484, 0.0251, 0.0, -0.024, -0.0374, -0.0346, -0.0269, -0.0175, -0.0106, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190627", "uid": "27f05f06-30bd-11ea-8bf7-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1332, 0.113, 0.0915, 0.0704, 0.0488, 0.0253, 0.0, -0.0241, -0.036, -0.0333, -0.0262, -0.0157, -0.0076, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20190628", "uid": "27f0cdd8-30bd-11ea-8066-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1324, 0.1126, 0.0912, 0.0708, 0.0488, 0.0257, 0.0, -0.0244, -0.0361, -0.0321, -0.0241, -0.0152, -0.0046, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190701", "uid": "27f1d334-30bd-11ea-8e1a-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1376, 0.1159, 0.0947, 0.0732, 0.0504, 0.0265, 0.0, -0.0254, -0.0349, -0.0287, -0.0199, -0.0105, 0.0001, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190702", "uid": "27f2352c-30bd-11ea-8ba0-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1419, 0.1206, 0.0977, 0.0756, 0.0527, 0.0276, 0.0, -0.0257, -0.0331, -0.0256, -0.0164, -0.0058, 0.0022, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190703", "uid": "27f2b5ec-30bd-11ea-a1ad-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1439, 0.1218, 0.0984, 0.0759, 0.0525, 0.0272, 0.0, -0.0257, -0.0325, -0.025, -0.0151, -0.0035, 0.0044, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190705", "uid": "27f32914-30bd-11ea-8ba1-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1445, 0.1212, 0.0988, 0.0756, 0.052, 0.0272, 0.0, -0.026, -0.0335, -0.0268, -0.0171, -0.0063, 0.0041, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20190708", "uid": "27f39d22-30bd-11ea-af47-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1435, 0.1207, 0.0993, 0.0755, 0.0524, 0.0274, 0.0, -0.0255, -0.0346, -0.0282, -0.0196, -0.0098, 0.0039, null], "yaxis": "y2", "type": "scatte ...
# ...
# <div id="be05c7f8-5154-40bf-bbb0-03060c69e364" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("be05c7f8-5154-40bf-bbb0-03060c69e364", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191021", "uid": "2913e478-30bd-11ea-a711-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1415, 0.1203, 0.0995, 0.0786, 0.0558, 0.0299, 0.0, -0.0269, -0.0366, -0.0287, -0.0177, -0.0081, 0.0026, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191022", "uid": "29147988-30bd-11ea-8f27-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1417, 0.1202, 0.0998, 0.0783, 0.0556, 0.0296, 0.0, -0.028, -0.0379, -0.0303, -0.0201, -0.0097, 0.0014, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191023", "uid": "2914fc3a-30bd-11ea-aa4a-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1429, 0.1211, 0.0996, 0.0785, 0.056, 0.0302, 0.0, -0.0272, -0.0364, -0.0292, -0.0192, -0.0093, 0.0009, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191024", "uid": "29156e06-30bd-11ea-bb36-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1419, 0.1209, 0.0991, 0.0782, 0.0552, 0.0297, 0.0, -0.0269, -0.0358, -0.0287, -0.0189, -0.0088, 0.0011, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191025", "uid": "29162cd8-30bd-11ea-8afe-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1441, 0.1216, 0.101, 0.0794, 0.0559, 0.0298, 0.0, -0.0255, -0.0329, -0.0247, -0.0148, -0.0047, 0.0047, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191028", "uid": "29175718-30bd-11ea-bd84-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1496, 0.1282, 0.1054, 0.0828, 0.0583, 0.0307, 0.0, -0.0243, -0.03, -0.0228, -0.0124, -0.0028, 0.0044, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191029", "uid": "2917cd68-30bd-11ea-85d0-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1494, 0.1277, null, 0.0833, 0.0592, 0.0313, 0.0, -0.0258, -0.0323, -0.025, -0.0142, -0.0037, 0.0088, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191030", "uid": "29183ffa-30bd-11ea-a109-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1492, 0.1274, 0.1049, 0.0832, 0.0582, 0.031, 0.0, -0.0265, -0.0321, -0.0247, -0.014, -0.0052, 0.0049, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191031", "uid": "2918da98-30bd-11ea-8a78-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1465, 0.1236, 0.1032, 0.0817, 0.0582, 0.0312, 0.0, -0.0274, -0.0359, -0.0283, -0.0169, -0.0054, 0.0059, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191101", "uid": "29194d78-30bd-11ea-810b-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1457, 0.125, 0.1028, 0.0812, 0.0571, 0.0306, 0.0, -0.0261, -0.0317, -0.023, -0.0118, 0.0001, null, null], "yaxis": "y2", "type": "scatter", "xaxis ...
# <div id="417bf42a-3165-4c97-a2fe-7cd90e1a2bc8" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("417bf42a-3165-4c97-a2fe-7cd90e1a2bc8", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191118", "uid": "292a3318-30bd-11ea-b83b-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1571, 0.1323, 0.1088, 0.0866, 0.0613, 0.0329, 0.0, -0.0279, -0.0303, -0.0203, -0.0077, 0.0037, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191119", "uid": "292afc9e-30bd-11ea-93bc-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1589, 0.1342, 0.11, 0.0862, 0.062, 0.0331, 0.0, -0.0285, -0.0317, -0.0209, -0.0106, -0.0015, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191120", "uid": "292ba3e2-30bd-11ea-869c-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1572, 0.1325, 0.1095, 0.0872, 0.062, 0.0339, 0.0, -0.0298, -0.0347, -0.0241, -0.0116, -0.0019, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191121", "uid": "292c7918-30bd-11ea-a5c3-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1558, 0.13, 0.1088, 0.0862, 0.0618, 0.0339, 0.0, -0.0309, -0.0358, -0.0258, -0.0144, -0.0031, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191122", "uid": "292d06ec-30bd-11ea-869a-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1545, 0.1301, 0.1075, 0.0853, 0.0619, 0.0338, 0.0, -0.0299, -0.0342, -0.0243, -0.0127, 0.0, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191125", "uid": "292df278-30bd-11ea-9a26-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1592, 0.1332, 0.1099, 0.0869, 0.0615, 0.0335, 0.0, -0.029, -0.0308, -0.0193, -0.0076, 0.0047, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191126", "uid": "292e9298-30bd-11ea-8bfd-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1621, 0.1351, 0.1116, 0.0878, 0.0625, 0.0338, 0.0, -0.0282, -0.0294, -0.0188, -0.0083, 0.0003, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191127", "uid": "292f3890-30bd-11ea-95d7-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1635, 0.1365, 0.1119, 0.0883, 0.0626, 0.0339, 0.0, -0.028, -0.0283, -0.017, -0.0045, 0.0055, null, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191129", "uid": "292faa8c-30bd-11ea-bbc0-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.164, 0.1365, 0.1114, 0.0892, 0.0633, 0.0342, 0.0, -0.0296, -0.0323, -0.0212, -0.0091, 0.0033, 0.0153, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191202", "uid": "293016b6-30bd-11ea-95d1-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1594, 0.1332, 0.1096, 0.0871, 0.0627, 0.0341, 0.0, -0.033, -0.0403, -0.0307, -0.0178, -0.0082, 0.0044, null], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}, {"legendgro ...
# <div id="73e84431-f82e-4fe3-adcf-ae31f57903f8" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("73e84431-f82e-4fe3-adcf-ae31f57903f8", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191217", "uid": "2941b146-30bd-11ea-8b50-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1884, 0.1578, 0.128, 0.0994, 0.0689, 0.0364, 0.0, -0.0235, -0.018, -0.0051, 0.0086, 0.0184, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191218", "uid": "2942202c-30bd-11ea-aa37-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1883, 0.1574, 0.1271, 0.0981, 0.0684, 0.0361, 0.0, -0.0236, -0.0195, -0.0071, 0.0051, 0.0166, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191219", "uid": "2942a7d8-30bd-11ea-b534-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1912, 0.1595, 0.1298, 0.0995, 0.0695, 0.0363, 0.0, -0.0236, -0.0179, -0.0082, 0.0077, 0.0246, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191220", "uid": "294323b4-30bd-11ea-96b4-8c859025e7f9", "x": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "y": [0.1917, 0.1615, 0.1302, 0.1012, 0.0708, 0.0366, 0.0, -0.0224, -0.0185, -0.0074, 0.0087, 0.0258, null, null], "yaxis": "y", "type": "scatter", "xaxis": "x"}], {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "ESH20 20191217 - 20191220", "x": 0.2275, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "xaxis": {"anchor": "y", "domain": [0.0, 0.455], "tickangle": 45, "ticktext": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "tickvals": [-0.3, -0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35], "type": "category"}, "yaxis": {"anchor": "x", "domain": [0.555, 1.0], "title": "vol skew"}, "xaxis2": {"anchor": "y2", "domain": [0.545, 1.0]}, "yaxis2": {"anchor": "x2", "domain": [0.555, 1.0]}, "xaxis3": {"anchor": "y3", "domain": [0.0, 0.455]}, "yaxis3": {"anchor": "x3", "domain": [0.0, 0.445]}, "xaxis4": {"anchor": "y4", "domain": [0.545, 1.0]}, "yaxis4": {"anchor": "x4", "domain": [0.0, 0.445]}, "font": {"family": "Open Sans, sans-serif"}, "margin": {"b": 55, "l": 45, "r": 15, "t": 50}, "title": "Skew plots<br>", "showlegend": true, "hovermode": "x", "autosize": true, "width": 900, "height": 800, "plot_bgcolor": "#EFECEA", "bargap": 0.05}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="5bf91c89-1175-457e-9ea2-1722a2e0d8ef" style="height: 800px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5bf91c89-1175-457e-9ea2-1722a2e0d8ef", [{"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191223", "uid": "29739d50-30bd-11ea-b413-8c859025e7f9", "x": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "y": [0.1189, 0.099, 0.0774, 0.0546, 0.0287, 0.0, -0.0248, -0.0344, -0.0314, -0.0251, -0.0181], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191224", "uid": "29740a88-30bd-11ea-80e2-8c859025e7f9", "x": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "y": [0.1169, 0.0976, 0.0768, 0.0539, 0.0283, 0.0, -0.0251, -0.0348, -0.0325, -0.0256, -0.0198], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191226", "uid": "29748aee-30bd-11ea-b552-8c859025e7f9", "x": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "y": [0.118, 0.0977, 0.0763, 0.0537, 0.0279, 0.0, -0.0243, -0.0336, -0.03, -0.0236, -0.0172], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191227", "uid": "2974fbfa-30bd-11ea-a99c-8c859025e7f9", "x": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "y": [0.1173, 0.0972, 0.0763, 0.0534, 0.0277, 0.0, -0.0252, -0.0355, -0.0327, -0.0266, -0.0167], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 1)", "name": "chart (1, 1) 20191230", "uid": "297569c8-30bd-11ea-9614-8c859025e7f9", "x": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "y": [0.1169, 0.0957, 0.0751, 0.0533, 0.0279, 0.0, -0.0258, -0.0377, -0.0354, -0.0295, -0.0229], "yaxis": "y", "type": "scatter", "xaxis": "x"}, {"legendgroup": "chart (1, 2)", "name": "chart (1, 2) 20191231", "uid": "2976799e-30bd-11ea-a49a-8c859025e7f9", "x": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "y": [0.1165, 0.0965, 0.0759, 0.0538, 0.0282, 0.0, -0.0267, -0.0363, -0.0336, -0.0279, -0.0214], "yaxis": "y2", "type": "scatter", "xaxis": "x2"}], {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "ESM20 20191223 - 20191230", "x": 0.2275, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "ESM20 20191231 - 20191231", "x": 0.7725, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "xaxis": {"anchor": "y", "domain": [0.0, 0.455], "tickangle": 45, "ticktext": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "tickvals": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "type": "category"}, "yaxis": {"anchor": "x", "domain": [0.555, 1.0], "title": "vol skew"}, "xaxis2": {"anchor": "y2", "domain": [0.545, 1.0], "tickangle": 45, "ticktext": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "tickvals": [-0.25, -0.2, -0.15, -0.1, -0.05, 0.0, 0.05, 0.1, 0.15, 0.2, 0.25], "type": "category"}, "yaxis2": {"anchor": "x2", "domain": [0.555, 1.0], "title": "vol skew"}, "xaxis3": {"anchor": "y3", "domain": [0.0, 0.455]}, "yaxis3": {"anchor": "x3", "domain": [0.0, 0.445]}, "xaxis4": {"anchor": "y4", "domain": [0.545, 1.0]}, "yaxis4": {"anchor": "x4", "domain": [0.0, 0.445]}, "font": {"family": "Open Sans, sans-serif"}, "margin": {"b": 55, "l": 45, "r": 15, "t": 50}, "title": "Skew plots<br>", "showlegend": true, "hovermode": "x", "autosize": true, "width": 900, "height": 800, "plot_bgcolor": "#EFECEA", "bargap": 0.05}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
clist
# Out:
# ['ESH19', 'ESM19', 'ESU19', 'ESZ19', 'ESH20', 'ESM20']

# %% [markdown]
# ## END
